# %%
import numpy as np
import pandas as pd
import datetime as dt
cols = ['ORIG','DEST','SALE_STR_DATE','TRAVEL_STR_DATE','SEASON_STR_DATE','DOW','MIN_STAY_UNIT','MIN_STAY_VAL','MAX_STAY_UNIT','MAX_STAY_VAL','FAREAMT_BC','AP_UNIT','AP_VALUE','RBD']
for i in range(1,8):
    cols.append('DAY_'+str(i))
path = 'test_100000_convered_units.csv'
df = pd.read_csv(path, usecols=cols)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-6299b0647808> in <module>()
#       7     cols.append('DAY_'+str(i))
#       8 path = 'test_10000_convered_units.csv'
# ----> 9 df = pd.read_csv(path, usecols=cols)
#
# ...

# %%
df.head()
# Out:
#    JRNY_TYPE_ID  ORIG  DEST  SALE_STR_DATE  TRAVEL_STR_DATE  SEASON_STR_DATE  \
# 0             2    15    36             59               59              228
# 1             2    15    78            144              144              195
# 2             2    38     2             59               59              242
# 3             2    37    62             59               59              186
# 4             2    42    52             59               59              187
#
#    MIN_STAY_VAL  MAX_STAY_VAL  AP_VALUE  RBD  DAY_1  DAY_2  DAY_3  DAY_4  \
# 0           7.0        262800       NaN    3      1      1      1      1
# 1           NaN        525600       NaN    7      0      0      0      1
# 2           NaN        525600       NaN    7      1      1      1      1
# 3           7.0        262800       NaN    0      1      1      1      1
# 4           7.0        262800       NaN    0      1      1      1      1
#
#    DAY_5  DAY_6  DAY_7
# 0      0      0      1
# ...

# %%
def is_number(x):
    res = isinstance(x, (int, float))
    if res is False:
        x = int(x)
        res = isinstance(x, (int, float))
    if res is False:
        print("failed!",res,x)
    return isinstance(x, (int, float))

# %%
# quant_features = ['MIN_STAY_VAL']#, 'registered', 'cnt', 'temp', 'hum', 'windspeed']
# # Store scalings in a dictionary so we can convert back later
# scaled_features = {}
# for each in quant_features:
# #     df.loc[:, each] = [str(x) for x in df[each]]
#     mean, std = df[each].mean(), df[each].std()
#     print(mean,std)
#     scaled_features[each] = [mean, std]
#     print((df[each] - mean)/std)
#     df.loc[:, each] = (df[each] - mean)/std

# %%
#replace NaN values with mean

# %%
for feature in cols:
    df[feature].fillna((df[feature].mean()), inplace=True)
#     for i in range(df[feature].size):
#         if df.loc[i,feature] == '':
#             df.loc[i,feature] = 0

# %%
df.head()
# Out:
#    JRNY_TYPE_ID  ORIG  DEST  SALE_STR_DATE  TRAVEL_STR_DATE  SEASON_STR_DATE  \
# 0             2    15    36             59               59              228
# 1             2    15    78            144              144              195
# 2             2    38     2             59               59              242
# 3             2    37    62             59               59              186
# 4             2    42    52             59               59              187
#
#    MIN_STAY_VAL  MAX_STAY_VAL     AP_VALUE  RBD  DAY_1  DAY_2  DAY_3  DAY_4  \
# 0      7.000000        262800  4449.313287    3      1      1      1      1
# 1      6.533127        525600  4449.313287    7      0      0      0      1
# 2      6.533127        525600  4449.313287    7      1      1      1      1
# 3      7.000000        262800  4449.313287    0      1      1      1      1
# 4      7.000000        262800  4449.313287    0      1      1      1      1
#
#    DAY_5  DAY_6  DAY_7
# ...

# %%
for feature in cols:
    for i in range(df[feature].size):
        if df.loc[i,feature] == '':
            df.loc[i,feature] = 0

# %%
df.head()
# Out:
#    JRNY_TYPE_ID  ORIG  DEST  SALE_STR_DATE  TRAVEL_STR_DATE  SEASON_STR_DATE  \
# 0             2    15    36             59               59              228
# 1             2    15    78            144              144              195
# 2             2    38     2             59               59              242
# 3             2    37    62             59               59              186
# 4             2    42    52             59               59              187
#
#   MIN_STAY_VAL  MAX_STAY_VAL AP_VALUE  RBD  DAY_1  DAY_2  DAY_3  DAY_4  DAY_5  \
# 0            7        262800        0    3      1      1      1      1      0
# 1            0        525600        0    7      0      0      0      1      1
# 2            0        525600        0    7      1      1      1      1      0
# 3            7        262800        0    0      1      1      1      1      0
# 4            7        262800        0    0      1      1      1      1      0
#
#    DAY_6  DAY_7
# 0      0      1
# ...

# %%
df.to_csv('test_100000_scaled.csv')
